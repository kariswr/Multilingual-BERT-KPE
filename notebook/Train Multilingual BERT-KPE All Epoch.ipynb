# %%
from google.colab import drive
from google.colab import files
import pandas as pd
import json
import os
import tensorflow as tf
import torch

# %%
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/TA/Sem 8")
# Out:
# Mounted at /content/drive

# %%
os.listdir()
# Out:
# ['toy-ende',
#  'dataset',
#  'indonlu-master',
#  'notebook',
#  'Draft Bab III.docx',
#  '13517031_Karina Iswara_Laporan M1.docx',
#  '13517031_Karina Iswara_Resume TA.gdoc',
#  'question-generator',
#  '13517031_Karina Iswara_Laporan M2.docx',
#  'models',
#  'view.1',
#  'test_ner.txt',
#  'test_dict_ner.txt',
#  'BERT-KPE',
#  'Multilingual-BERT-KPE']

# %%
# !git clone https://github.com/kariswr/Multilingual-BERT-KPE.git

# %%
# !pwd
# %cd Multilingual-BERT-KPE/
os.listdir()
# Out:
# /content/drive/My Drive/TA/Sem 8
# /content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE
# ['.git',
#  '.DS_Store',
#  '.gitignore',
#  'LICENSE',
#  'README.md',
#  'bertkpe',
#  'preprocess',
#  'scripts',
#  'dataset',
#  'pretrain_model',
#  'results',
#  'prepro_dataset',
#  'cache_features',
#  'checkpoints',
#  'api']

# %%
# !git pull
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 9 (delta 6), reused 8 (delta 5), pack-reused 0
# Unpacking objects: 100% (9/9), done.
# From https://github.com/kariswr/Multilingual-BERT-KPE
#    4942816..95f7c59  master     -> origin/master
# Updating 4942816..95f7c59
# Fast-forward
#  api/answer_extractor.py | 3 ---
#  api/api_endpoint.py     | 4 +++-
#  scripts/test.py         | 4 ++--
#  3 files changed, 5 insertions(+), 6 deletions(-)

# %% [markdown]
# ### Preprocess Dataset

# %%
# !python ./preprocess/preprocess.py --dataset_class squad \
--source_dataset_dir "dataset" \
--output_path "prepro_dataset" \
# Out:
# 1204it [00:01, 1081.43it/s]
# 100% 1204/1204 [00:00<00:00, 2893.05it/s]
# 100% 1165/1165 [00:03<00:00, 297.65it/s]
# 100% 1165/1165 [00:00<00:00, 108527.99it/s]
# 100% 1165/1165 [00:00<00:00, 24106.86it/s]
# 1904it [00:00, 2249.99it/s]
# 100% 1904/1904 [00:00<00:00, 3294.82it/s]
# 100% 1845/1845 [00:05<00:00, 353.33it/s]
# 100% 1845/1845 [00:00<00:00, 119555.84it/s]
# 100% 1845/1845 [00:00<00:00, 30289.89it/s]
# 17131it [00:01, 9066.27it/s]
# 100% 17131/17131 [00:04<00:00, 3605.52it/s]
# 100% 16635/16635 [00:43<00:00, 383.66it/s]
# 100% 16628/16628 [00:00<00:00, 31365.09it/s]

# %%
# !pip install boto3
# !pip install sacremoses
# !pip install torch==1.8.1
# !pip install tensorboardx
# Out:
# ...
#      |████████████████████████████████| 131 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 7.9 MB 30.5 MB/s
# ...
#      |████████████████████████████████| 79 kB 7.0 MB/s
# ...
#      |████████████████████████████████| 138 kB 58.5 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.6 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...
#      |████████████████████████████████| 895 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 804.1 MB 2.8 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu102
# ...

# %%
# !pwd
# Out:
# /content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE

# %% [markdown]
# ### Epoch 10

# %%
# %cd scripts
# !python test.py --run_mode test \
--local_rank -1 \
--max_train_epochs 10 \
--model_class bert2joint \
--pretrain_model_type bert-base-multilingual-cased \
--dataset_class squad \
--per_gpu_test_batch_size 8 \
--preprocess_folder "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/prepro_dataset" \
--pretrain_model_path "" \
--cached_features_dir "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/cache_features" \
--eval_checkpoint "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/results/epoch_10/2/train_bert2joint_squad_bert_08.28_10.51/checkpoints/bert2joint.squad.bert.epoch_10.checkpoint" \
--save_path "../results/epoch_10/2"
# Out:
# [Errno 2] No such file or directory: 'scripts'
# /content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/scripts
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2021-09-05 18:49:01.430536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-05 18:49:01.439830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-05 18:49:01.440858: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# ### Epoch 20

# %%
# %cd scripts
# !python train.py \
--run_mode train \
--local_rank -1 \
--max_train_epochs 20 \
--model_class bert2joint \
--dataset_class squad \
--pretrain_model_type bert-base-multilingual-cased \
--per_gpu_train_batch_size 8 \
--gradient_accumulation_steps 4 \
--per_gpu_test_batch_size 32 \
--preprocess_folder "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/prepro_dataset" \
--pretrain_model_path "" \
--cached_features_dir "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/cache_features" \
--display_iter 200 \
--save_checkpoint \
--save_path "../results/epoch_20/2"
# Out:
# /content/drive/.shortcut-targets-by-id/1qezQJJmMkl2M7WJYXoN9ZLtMlpV64TQ_/TA/Sem 8/Multilingual-BERT-KPE/scripts
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2021-08-28 14:20:59.959198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-28 14:21:00.277793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-28 14:21:00.278433: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# %cd scripts
# !python test.py --run_mode test \
--local_rank -1 \
--model_class bert2joint \
--pretrain_model_type bert-base-multilingual-cased \
--dataset_class squad \
--per_gpu_test_batch_size 8 \
--preprocess_folder "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/prepro_dataset" \
--pretrain_model_path "" \
--cached_features_dir "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/cache_features" \
--eval_checkpoint "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/results/epoch_20/2/train_bert2joint_squad_bert_08.28_14.21/checkpoints/bert2joint.squad.bert.epoch_20.checkpoint" \
--save_path "../results/epoch_20/2"
# Out:
# [Errno 2] No such file or directory: 'scripts'
# /content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/scripts
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2021-09-05 18:43:39.895163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-05 18:43:39.906198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-05 18:43:39.906936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# ### Epoch 30

# %%
# %cd scripts
# !python train.py \
--run_mode train \
--local_rank -1 \
--max_train_epochs 30 \
--model_class bert2joint \
--dataset_class squad \
--pretrain_model_type bert-base-multilingual-cased \
--per_gpu_train_batch_size 8 \
--gradient_accumulation_steps 4 \
--per_gpu_test_batch_size 32 \
--preprocess_folder "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/prepro_dataset" \
--pretrain_model_path "" \
--cached_features_dir "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/cache_features" \
--display_iter 200 \
--save_checkpoint \
--save_path "../results/epoch_30/1"
# Out:
# /content/drive/.shortcut-targets-by-id/1qezQJJmMkl2M7WJYXoN9ZLtMlpV64TQ_/TA/Sem 8/Multilingual-BERT-KPE/scripts
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2021-08-29 19:05:29.327749: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-29 19:05:29.757025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-29 19:05:29.758080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# %cd scripts
# !python test.py --run_mode test \
--local_rank -1 \
--model_class bert2joint \
--pretrain_model_type bert-base-multilingual-cased \
--dataset_class squad \
--per_gpu_test_batch_size 8 \
--preprocess_folder "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/prepro_dataset" \
--pretrain_model_path "" \
--cached_features_dir "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/cache_features" \
--eval_checkpoint "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/results/epoch_30/1/train_bert2joint_squad_bert_08.29_19.05/checkpoints/bert2joint.squad.bert.epoch_30.checkpoint" \
--save_path "../results/epoch_30/1"
# Out:
# [Errno 2] No such file or directory: 'scripts'
# /content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/scripts
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2021-09-05 18:31:48.706892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-05 18:31:48.716147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-05 18:31:48.717067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# ### Epoch 40

# %%
# %cd scripts
# !python train.py \
--run_mode train \
--local_rank -1 \
--max_train_epochs 40 \
--model_class bert2joint \
--dataset_class squad \
--pretrain_model_type bert-base-multilingual-cased \
--per_gpu_train_batch_size 8 \
--gradient_accumulation_steps 4 \
--per_gpu_test_batch_size 32 \
--preprocess_folder "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/prepro_dataset" \
--pretrain_model_path "" \
--cached_features_dir "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/cache_features" \
--display_iter 200 \
--save_checkpoint \
--save_path "../results/epoch_40/1"
# Out:
# /content/drive/.shortcut-targets-by-id/1qezQJJmMkl2M7WJYXoN9ZLtMlpV64TQ_/TA/Sem 8/Multilingual-BERT-KPE/scripts
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2021-08-30 19:26:59.484304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-30 19:26:59.953431: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-30 19:26:59.954083: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# %cd scripts
# !python test.py --run_mode test \
--local_rank -1 \
--model_class bert2joint \
--pretrain_model_type bert-base-multilingual-cased \
--dataset_class squad \
--per_gpu_test_batch_size 8 \
--preprocess_folder "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/prepro_dataset" \
--pretrain_model_path "" \
--cached_features_dir "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/cache_features" \
--eval_checkpoint "/content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/results/epoch_40/1/train_bert2joint_squad_bert_08.30_19.27/checkpoints/bert2joint.squad.bert.epoch_40.checkpoint" \
--save_path "../results/epoch_40/1"
# Out:
# /content/drive/My Drive/TA/Sem 8/Multilingual-BERT-KPE/scripts
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2021-09-05 18:26:22.702339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-05 18:26:23.354230: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-05 18:26:23.355182: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
